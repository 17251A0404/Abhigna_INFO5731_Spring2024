# %% [markdown]
# <a href="https://colab.research.google.com/github/17251A0404/Abhigna_INFO5731_Spring2024/blob/main/INFO5731_Assignment_1_Spring_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment One**

# %% [markdown]
# This assignment includes range of programming tasks and data analysis exercises, aiming to enhance your Python skills and proficiency in string manipulation, numerical computations, and data science. Follow the instructions carefully and design well-structured Python programs to address each question.
#
# Late Submission will have a penalty of 10% reduction for each day after the deadline.

# %% [markdown]
# # Question 1 (10 points).
#
# The formula that describes the volume V of a hemisphere with radius r is the following:
#
# $ V=\frac{2}{3}\ast\ \pi\ast\ r^3 $
#
# Write a program to calculate the value of V when r is in the range of even numbers from 1-20. Output the result in the following format:
#
# 	r	V
# 	2	…
# 	4	…
# 	6	…
# 	.
# 	.
# 	.
# 	20	…

# %%
# Your code here
import math
print("r    V")
for r in range(2, 21, 2):
    V = (2/3) * math.pi * (r**3)
    print( r  ,  V)
# Out:
# r    V
# 2 16.755160819145562
# 4 134.0412865531645
# 6 452.38934211693015
# 8 1072.330292425316
# 10 2094.3951023931954
# 12 3619.114736935441
# 14 5747.0201609669275
# 16 8578.642339402528
# 18 12214.512237157114
# 20 16755.160819145563

# %% [markdown]
# # Question 2 (20 points)
#
# (a) Write a Python program to generate a sequence of 12 random numbers falling within the range of 50 to 150.
#
# (b) Arrange the generated numbers in ascending order. Display the sorted list.
#
# (c) Extend the program to arrange the numbers in descending order as well. Present the sorted list accordingly.
#
# (d) Compute and output the average of the entire group of generated numbers.
#
# (e) Enhance the program to calculate and display the average of the first 6 numbers from both the ascending and descending sorted lists.

# %%
# Write code for each of the sub parts with proper comments.
#(a) 12 Random Numbers:
import random
lower_num = 50
upper_num = 150
print("12 random numbers:")
for _ in range(12):
    random_nums = random.randint(lower_num, upper_num)
    print(random_nums)

#(b) ASCENDING ORDER:
nums = [58, 91, 100, 98, 114, 133, 52, 95, 56, 121, 116, 96]
sorted_nums = sorted(nums)
print("Ascending Order:")
for num in sorted_nums:
    print(num)
#(c) Descending Order:
nums = [58, 91, 100, 98, 114, 133, 52, 95, 56, 121, 116, 96]
sorted_desc = sorted(nums, reverse=True)
print( "Descending Order:")
for num in sorted_desc:
    print(num)
#(d) Average:
nums = [58, 91, 100, 98, 114, 133, 52, 95, 56, 121, 116, 96]
avg = sum(nums) / len(nums)
print("Average:", avg)
#(e)average of the first 6 numbers from both the ascending and descending sorted lists:
nums = [58, 91, 100, 98, 114, 133, 52, 95, 56, 121, 116, 96]
asc_order = sorted(nums)
desc_order = sorted(nums, reverse=True)
avg_asc = sum(asc_order[:6]) / 6
avg_desc = sum(desc_order[:6]) / 6
print("Average of First 6 Ascending Numbers:", avg_asc)
print("Average of First 6 Descending Numbers:", avg_desc)
# Out:
# 12 random numbers:
# 111
# 107
# 134
# 149
# 51
# 87
# 103
# 83
# 121
# 148
# 142
# 56
# Ascending Order:
# 52
# 56
# 58
# 91
# 95
# 96
# 98
# 100
# 114
# 116
# 121
# 133
# Descending Order:
# 133
# 121
# 116
# 114
# 100
# 98
# 96
# 95
# 91
# 58
# 56
# 52
# Average: 94.16666666666667
# Average of First 6 Ascending Numbers: 74.66666666666667
# Average of First 6 Descending Numbers: 113.66666666666667

# %% [markdown]
# # Question 3 (20 points).
#
# Create a Python program that encompasses various string manipulation task:
#
# (a) Prompt the user to input two sentences.
#
# (b) Transform each sentence into a list, where each element corresponds to a word in the sentence. For example, if the sentences are "Hello, how are you doing today?" and "This is an example sentence for the program!"
#
# The program should output:
# ['Hello', ',', 'how', 'are', 'you', 'doing', 'today', '?', 'This', 'is', 'an', 'example', 'sentence', 'for', 'the', 'program', '!']
#
# (c) Compare the two sentences. Print out a list of words that occur in both sentences.
#
# (d) Remove any punctuation from the sentence and print the sanitized sentences. It should remove at least the following characters, but it can remove more: period(“.”), comma (“,”), semicolon (“;”), and colon (“:”).
#
# (e) Count the number of vowels in each of the sentences. Print out each vowel and the occurrences  in the each of the two sentences separately, such as:
#
# Sentence1: a:2, e:2, i:0, etc.
# Sentence2: a:1, e:2, i:2, etc.
#
# Design a well-structured Python program to execute these tasks efficiently.

# %%
#(a) Prompt the user to input two sentences.
s1 = input("Enter the first sentence: ")
s2 = input("Enter the second sentence: ")
print("Sentence 1:", s1)
print("Sentence 2:", s2)

#(b)Transform each sentence into a list,
s1= "Hello, how are you doing today ?"
s2=  "This is an example sentence for the program !"
list1 = s1.split()
list2 = s2.split()
list_final = list1 + list2
print("Sentence into list:")
print(list_final)

#(c) list of words that occur in both sentences
s1 = input("Enter the first sentence: ")
s2 = input("Enter the second sentence: ")
list1 = s1.split()
list2 = s2.split()
common_words = set(list1) & set(list2)
print("Common Words in Both Sentences:")
print(list(common_words))

#(d) Remove any punctuations and print sanitized sentences
import string
s1 = "Hello, how are you doing today?"
s2 =  "This is an example sentence for the program!"
translator = str.maketrans("", "", string.punctuation)
sanitized_s1 = s1.translate(translator)
sanitized_s2 = s2.translate(translator)
print("\nSanitized Sentences:")
print("Sentence 1:", sanitized_s1)
print("Sentence 2:", sanitized_s2)

#(e)Count the number of vowels and print out each vowel and the occurrences
s1 = input("enter sentence 1")
s2 = input("enter sentence 2")
def count_vowels(sentence):
    vowels = "aeiouAEIOU"
    v_count = {vowel: 0 for vowel in vowels}

    for char in sentence:
        if char in vowels:
            v_count[char] += 1

    return v_count
v_count1 = count_vowels(s1)
v_count2 = count_vowels(s2)
print("\nVowel Counts:")
print("Sentence 1:", {k: v for k, v in v_count1.items() if v > 0})
print("Sentence 2:", {k: v for k, v in v_count2.items() if v > 0})
# Out:
# Enter the first sentence: swee likes frui
# Enter the second sentence: frui likes swee
# Sentence 1: swee likes frui
# Sentence 2: frui likes swee
# Sentence into list:
# ['Hello,', 'how', 'are', 'you', 'doing', 'today', '?', 'This', 'is', 'an', 'example', 'sentence', 'for', 'the', 'program', '!']
# Enter the first sentence: hey hii!
# Enter the second sentence: hii , hru
# Common Words in Both Sentences:
# []
#
# Sanitized Sentences:
# Sentence 1: Hello how are you doing today
# Sentence 2: This is an example sentence for the program
# enter sentence 1fruitylovessweety
# enter sentence 2abhilovesprag
#
# Vowel Counts:
# Sentence 1: {'e': 3, 'i': 1, 'o': 1, 'u': 1}
# Sentence 2: {'a': 2, 'e': 1, 'i': 1, 'o': 1}

# %% [markdown]
# # Question 4 (20 Points)

# %% [markdown]
# Design and implement a simple command-line calculator program. The program should handle both integers and floating-point numbers.
#
# (a) Write program that takes a mathematical expression as input and evaluates it. The program should support addition, subtraction, multiplication, and division.
#
# (b) Extend the calculator to handle parentheses in mathematical expressions. Implement the necessary logic to evaluate expressions with nested parentheses.
#
# (c) Enhance your calculator to include additional mathematical operations such as exponentiation, square root, and modulus.
#
# (d) Implement error handling in the calculator program. Handle cases such as division by zero and invalid input expressions. Provide meaningful error messages.
#
# (e) Implement a command to exit the calculator.

# %%
# Your code here
#(a)Write program that takes a mathematical expression
import re
def calculate(exp):
    op = re.findall(r'\d+\.?\d*|\+|\-|\*|\/', exp)
    result = float(op[0])
    operator = None
    for token in op[1:]:
        if token in ['+', '-', '*', '/']:
            operator = token
        else:
            operand = float(token)
            if operator == '+':
                result += operand
            elif operator == '-':
                result -= operand
            elif operator == '*':
                result *= operand
            elif operator == '/':
                if operand != 0:
                    result /= operand
                else:
                    print("Error: Division by zero.")
                    return None

    return result
exp = input("Enter a mathematical expression: ")

result = calculate(exp)
if result is not None:
    print("Result:", result)

#(b) Extend the calculator to handle parentheses in mathematical expressions:

import re
def calculate(exp):
    try:
        return eval(exp)
    except ZeroDivisionError:
        return "Error: Division by zero"
    except Exception as e:
        return f"Error: {str(e)}"

def evaluate_with_parentheses(exp):
    while '(' in exp:

        innermost_start = exp.rfind('(')
        innermost_end = exp.find(')', innermost_start)

        if innermost_end == -1:
            print("Error: Unmatched parentheses.")
            return None
        inner_exp = exp[innermost_start + 1 : innermost_end]
        inner_result = calculate(inner_exp)

        if isinstance(inner_result, str) and inner_result.startswith("Error"):
            return inner_result
        exp = (
            exp[:innermost_start]
            + str(inner_result)
            + exp[innermost_end + 1 :]
        )

    return exp

def main():
    print("Extended Command-Line Calculator")
    print("Supported operations: +, -, *, /")
    print("Type 'exit' to quit")

    while True:
        exp = input("Enter exp: ")

        if exp.lower() == 'exit':
            break
        if not re.match(r'^[0-9+\-*/(). ]+$', exp):
            print("Invalid input. Please enter a valid exp.")
            continue
        exp = evaluate_with_parentheses(exp)
        if exp is None:
            continue
        result = calculate(exp)
        print("Result:", result)

if __name__ == "__main__":
    main()

#(c)Enhance your calculator to include additional mathematical operations such as exponentiation, square root, and modulus.
import math
def calculator():
    print("Welcome to the Enhanced Calculator!")
    print("Operations available:")
    print("1. Addition (+)")
    print("2. Subtraction (-)")
    print("3. Multiplication (*)")
    print("4. Division (/)")
    print("5. Exponentiation (**)")
    print("6. Square Root (√)")
    print("7. Modulus (%)")
    print("0. Exit")
    while True:
        choice = input("Enter operation number: ")

        if choice == '0':
            print("Exiting the calculator. Goodbye!")
            break

        if choice in ('1', '2', '3', '4', '5', '6', '7'):
            num1 = float(input("Enter first number: "))
            if choice != '6':
                num2 = float(input("Enter second number: "))

            if choice == '1':
                print("Result:", num1 + num2)
            elif choice == '2':
                print("Result:", num1 - num2)
            elif choice == '3':
                print("Result:", num1 * num2)
            elif choice == '4':
                if num2 != 0:
                    print("Result:", num1 / num2)
                else:
                    print("Error! Division by zero.")
            elif choice == '5':
                print("Result:", num1 ** num2)
            elif choice == '6':
                if num1 >= 0:
                    print("Result:", math.sqrt(num1))
                else:
                    print("Error! Cannot calculate square root of a negative number.")
            elif choice == '7':
                print("Result:", num1 % num2)
        else:
            print("Invalid choice. Please enter a valid operation number.")
calculator()

#(d)Handle cases such as division by zero and invalid input expressions in the calculator program
def calculate(exp):
    try:
        result = eval(exp)
        return result
    except ZeroDivisionError:
        return "Error: Division by zero is not allowed."
    except SyntaxError:
        return "Error: Invalid expression. Please enter a valid mathematical expression."
    except Exception as e:
        return f"An unexpected error occurred: {str(e)}"

def main():
    print("Type 'exit' to end the program.")
    while True:
        user_input = input("Enter a mathematical expression: ")

        if user_input.lower() == 'exit':
            break

        result = calculate(user_input)
        print(f"Result: {result}\n")

if __name__ == "__main__":
    main()

 #(e)Implement a command to exit the calculator.
    def calculator():
      while True:
        user_input = input("Enter a math expression or type 'exit' to quit: ")

        if user_input.lower() == 'exit':
            print("Exiting the calculator.")
            break

        try:
            result = eval(user_input)
            print("Result:", result)
        except Exception as e:
            print("Error:", e)

if __name__ == "__main__":
    calculator()
# Out:
# Enter a mathematical expression: 4+6-2*1
# Result: 8.0
# Extended Command-Line Calculator
# Supported operations: +, -, *, /
# Type 'exit' to quit
# Enter exp: (2+6)-3*2
# Result: 2
# Enter exp: exit
# Welcome to the Enhanced Calculator!
# Operations available:
# 1. Addition (+)
# 2. Subtraction (-)
# 3. Multiplication (*)
# 4. Division (/)
# 5. Exponentiation (**)
# 6. Square Root (√)
# 7. Modulus (%)
# 0. Exit
# Enter operation number: 5
# Enter first number: 5
# Enter second number: 2
# Result: 25.0
# Enter operation number: 6
# Enter first number: 5
# Result: 2.23606797749979
# Enter operation number: 7
# Enter first number: 3
# Enter second number: 2
# Result: 1.0
# Enter operation number: 0
# Exiting the calculator. Goodbye!
# Type 'exit' to end the program.
# Enter a mathematical expression: (3+2-1+5*1)*0
# Result: 0
#
# Enter a mathematical expression: (6+3-2)/0
# Result: Error: Division by zero is not allowed.
#
# Enter a mathematical expression: 4+1&
# ...

# %% [markdown]
# # Question 5 (30 points).
#
# In the field of Data Science, data is often formatted as a comma-delimited (CSV) file, where each line in a file corresponds to a field's value. Refer to Chapter 9 (p. 106) for more information on comma-delimited files.
#
# To answer this question, you will need to download the file [Assignment1_denton_housing.csv](https://raw.githubusercontent.com/unt-iialab/info5731-spring2022/main/assignments/Assignment1_denton_housing.csv) included with this assignment. The file contains statistics about housing in the city of Denton from 2008 to 2014. Write a program to implement the following questions.
#
# (a) (5 pts) Calculate the difference in the number of Occupied Housing Units from year to year and print it. The difference must be calculated for the consecutive years such as 2008-2009, 2009-2010 etc. Finally, print the values in the ascending order.
#
# (b) (5 pts) For all the years, calculate the percentage of housing units which are vacant an occupied. Print the results in the following format:
#
# Year Vacant Housing Units Occupied Housing Units
#
#     2008  30%   70%
# 	2009 ----- -----
# 	2010 ----- -----
#     2011 ----- -----
# 	2012 ----- -----
#     2013 ----- -----
# 	2014 ----- -----
#
#
#
# (c) (10 pts) Calculate and print the valued and years in which the highest number of housing units were vacant and occupied. Print the results in the following format:
#
#                               Year	Value
# 	Vacant Housing Units	  -----   -----
# 	Occupied Housing Units	-----   -----
#
# (d) (10 pts) Calculate the harmonic mean of the total housing units and print it out. You can find the information about harmonic mean here: https://ncalculators.com/statistics/harmonic-mean-calculator.htm

# %%
# a

import csv
final_list = []
with open('/content/sample_data/data.csv', mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
        if row[1] == "Occupied Housing Units":
            final_list.append({"year": int(row[0]), "value": int(row[2])})

sorted_list = sorted(final_list, key=lambda x: x["year"])

values = []
for i in range(len(sorted_list)-2):
    if sorted_list[i+1]['year'] ==  sorted_list[i]['year'] + 1:
        values.append(sorted_list[i+1]['value']-sorted_list[i]['value'])

sorted_values = sorted(values)
for value in sorted_values:
  print(value)


# b

final_list = []
years = []
total = []
vacant, occupied = [], []
with open('/content/sample_data/data.csv', mode='r') as file:
    reader = csv.reader(file)
    for i, row in enumerate(reader):
      if i ==0:
        continue
      if int(row[0]) not in years:
          years.append(int(row[0]))
      if row[1] == "Total Housing Units":
          total.append(int(row[2]))
      elif row[1] == "Vacant Housing Units":
          vacant.append(int(row[2]))
      elif row[1] == "Occupied Housing Units":
          occupied.append(int(row[2]))
for i, year in enumerate(years):
    print(f"{year} {vacant[i]*100/total[i]} {occupied[i]*100/total[i]}")

#c

occupied_list, vacant_list = [], []
with open('/content/sample_data/data.csv', mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
        if row[1] == "Occupied Housing Units":
            occupied_list.append({"year": int(row[0]), "value": int(row[2])})
        elif row[1] == "Vacant Housing Units":
            vacant_list.append({"year": int(row[0]), "value": int(row[2])})

sorted_occupied_list = sorted(occupied_list, key=lambda x: x["year"])
sorted_vacant_list = sorted(vacant_list, key=lambda x: x["year"])

print(f"Vacant Housing Units {sorted_vacant_list[-1]['year']} {sorted_vacant_list[-1]['value']}")
print(f"Occupied Housing Units {sorted_occupied_list[-1]['year']} {sorted_occupied_list[-1]['value']}")


# d

import statistics
total = []
with open('/content/sample_data/data.csv', mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
        if row[1] == "Total Housing Units":
            total.append(int(row[2]))
print(statistics.harmonic_mean(total))
# Out:
# -795
# -303
# 1404
# 1565
# 5091
# 2008 5.730110570363885 94.26988942963611
# 2009 8.801787504176412 91.19821249582358
# 2010 6.677600230491345 93.32239976950865
# 2011 9.379522229890688 90.62047777010932
# 2012 8.142556337081672 91.85744366291833
# 2013 9.07111572444872 90.92888427555128
# 2014 10.88265281351653 89.11734718648347
# Vacant Housing Units 2014 2814
# Occupied Housing Units 2014 46295
# 44398.28543969185

# %% [markdown]
# # Mandatory Question
#
# Provide your thoughts on the assignment. What did you find challenging, and what aspects did you enjoy? Your opinion on the provided time to complete the assignment. Share any suggestions for improvement. Your feedback will be valuable for enhancing the learning experience.

# %%
I think i felt little comfortable when compared to previous inclass exercise.last 2 questions are little bit challenging questions but i enjoyed while writing the code.
