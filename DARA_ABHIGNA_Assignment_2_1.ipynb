# %% [markdown]
# <a href="https://colab.research.google.com/github/17251A0404/Abhigna_INFO5731_Spring2024/blob/main/DARA_ABHIGNA_Assignment_2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment 2**
#
# In this assignment, you will work on gathering text data from an open data source via web scraping or API. Following this, you will need to clean the text data and perform syntactic analysis on the data. Follow the instructions carefully and design well-structured Python programs to address each question.
#
# **Expectations**:
# *   Use the provided .*ipynb* document to write your code & respond to the questions. Avoid generating a new file.
# *   Write complete answers and run all the cells before submission.
# *   Make sure the submission is "clean"; *i.e.*, no unnecessary code cells.
# *   Once finished, allow shared rights from top right corner (*see Canvas for details*).
#
# * **Make sure to submit the cleaned data CSV in the comment section - 10 points**
#
# **Total points**: 100
#
# **Deadline**: Wednesday, at 11:59 PM.
#
# **Late Submission will have a penalty of 10% reduction for each day after the deadline.**

# %% [markdown]
# # Question 1 (40 points)
#
# Write a python program to collect text data from **either of the following sources** and save the data into a **csv file:**
#
# (1) Collect all the customer reviews of a product (you can choose any porduct) on amazon. [atleast 1000 reviews]
#
# (2) Collect the top 1000 User Reviews of a movie recently in 2023 or 2024 (you can choose any movie) from IMDB. [If one movie doesn't have sufficient reviews, collect reviews of atleast 2 or 3 movies]
#
# (3) Collect all the reviews of the top 1000 most popular software from G2 or Capterra.
#
# (4) Collect the **abstracts** of the top 10000 research papers by using the query "machine learning", "data science", "artifical intelligence", or "information extraction" from Semantic Scholar.
#
# (5) Collect all the information of the 904 narrators in the Densho Digital Repository.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def scrape_imdb_movie_reviews(movie_id, num_reviews=1000):
    base_url = f"https://www.imdb.com/title/{movie_id}/reviews"
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"}

    reviews = []
    page_num = 1
    while len(reviews) < num_reviews:
        url = f"{base_url}?sort=submissionDate&dir=desc&ratingFilter=0&page={page_num}"
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        review_containers = soup.find_all('div', class_='review-container')
        if not review_containers:
            break
        for container in review_containers:
            review_text = container.find('div', class_='text').text.strip()
            reviews.append(review_text)
            if len(reviews) >= num_reviews:
                break
        page_num += 1

    return reviews

def save_reviews_to_csv(reviews, filename):
    df = pd.DataFrame(reviews, columns=['Review'])
    df.to_csv(filename, index=False)

def main():
    # Movie ID of the movie you want to collect reviews for (IMDB ID can be found in the movie's IMDB URL)
    movie_id = "tt0172495"  # Example movie: The Matrix
    num_reviews = 1000  # Number of reviews to collect
    filename = "movie_reviews.csv"

    reviews = scrape_imdb_movie_reviews(movie_id, num_reviews)
    save_reviews_to_csv(reviews, filename)
    print(f"{len(reviews)} reviews saved to {filename}.")

if __name__ == "__main__":
    main()
# Out:
# 1000 reviews saved to movie_reviews.csv.

# %% [markdown]
# # Question 2 (30 points)
#
# Write a python program to **clean the text data** you collected in the previous question and save the clean data in a new column in the csv file. The data cleaning steps include: [Code and output is required for each part]
#
# (1) Remove noise, such as special characters and punctuations.
#
# (2) Remove numbers.
#
# (3) Remove stopwords by using the stopwords list.
#
# (4) Lowercase all texts
#
# (5) Stemming.
#
# (6) Lemmatization.

# %%
# Write code for each of the sub parts with proper comments.
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
import string

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

def remove_noise(text):
    # Remove special characters and punctuations
    text = ''.join([char for char in text if char not in string.punctuation])
    return text

def remove_numbers(text):
    # Remove numbers
    text = ''.join([char for char in text if not char.isdigit()])
    return text

def remove_stopwords(text):
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    words = word_tokenize(text)
    filtered_text = ' '.join([word for word in words if word.lower() not in stop_words])
    return filtered_text

def lowercase(text):
    # Lowercase all texts
    return text.lower()

def stemming(text):
    # Stemming
    stemmer = PorterStemmer()
    words = word_tokenize(text)
    stemmed_text = ' '.join([stemmer.stem(word) for word in words])
    return stemmed_text

def lemmatization(text):
    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    words = word_tokenize(text)
    lemmatized_text = ' '.join([lemmatizer.lemmatize(word) for word in words])
    return lemmatized_text

def clean_text(text):
    text = remove_noise(text)
    text = remove_numbers(text)
    text = remove_stopwords(text)
    text = lowercase(text)
    text = stemming(text)
    text = lemmatization(text)
    return text

def clean_and_save_reviews(filename):
    df = pd.read_csv(filename)
    df['Cleaned_Review'] = df['Review'].apply(clean_text)
    cleaned_filename = filename.split('.')[0] + '_cleaned.csv'
    df.to_csv(cleaned_filename, index=False)
    print(f"Cleaned data saved to {cleaned_filename}.")

if __name__ == "__main__":
    filename = "movie_reviews.csv"  # Change this to your CSV filename
    clean_and_save_reviews(filename)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# Cleaned data saved to movie_reviews_cleaned.csv.

# %% [markdown]
# # Question 3 (30 points)
#
# Write a python program to **conduct syntax and structure analysis of the clean text** you just saved above. The syntax and structure analysis includes:
#
# (1) **Parts of Speech (POS) Tagging:** Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.
#
# (2) **Constituency Parsing and Dependency Parsing:** print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) **Named Entity Recognition:** Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %%
import spacy
from spacy import displacy
import pandas as pd
from collections import Counter

# Load the English language model
nlp = spacy.load("en_core_web_sm")

def pos_tagging_and_count(text):
    # Tag Parts of Speech of each word in the text and calculate the count of each POS
    doc = nlp(text)
    pos_tags = [token.pos_ for token in doc]
    pos_counts = Counter(pos_tags)
    return pos_counts

def constituency_and_dependency_parsing(text):
    # Print out the constituency parsing trees and dependency parsing trees of all the sentences
    doc = nlp(text)
    for sentence in doc.sents:
        print(f"Sentence: {sentence.text}")
        print("Parts of Speech:")
        for token in sentence:
            print(f"{token.text}/{token.pos_}", end=" ")
        print("\nConstituency Parsing Tree:")
        for np in sentence.noun_chunks:
            print(f"{np.text}/{np.root.dep_}", end=" ")
        print("\nDependency Parsing Tree:")
        displacy.render(sentence, style="dep", jupyter=True, options={"distance": 120})

def named_entity_recognition(text):
    # Extract named entities and calculate the count of each entity type
    doc = nlp(text)
    entities = Counter([(ent.text, ent.label_) for ent in doc.ents])
    return entities

def main():
    filename = "movie_reviews_cleaned.csv"  # Change this to your cleaned CSV filename
    df = pd.read_csv(filename)
    text = ' '.join(df['Cleaned_Review'])

    # Parts of Speech Tagging and Count
    pos_counts = pos_tagging_and_count(text)
    print("Parts of Speech (POS) Tagging:")
    print(pos_counts)

    # Constituency and Dependency Parsing
    print("\nConstituency and Dependency Parsing:")
    constituency_and_dependency_parsing(text)

    # Named Entity Recognition
    entities = named_entity_recognition(text)
    print("\nNamed Entity Recognition (NER):")
    print(entities)

if __name__ == "__main__":
    main()
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="914f4a4d7203407684677519840ac4e2-0" class="displacy" width="12290" height="797.0" direction="ltr" style="max-width: none; height: 797.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="707.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">though</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="707.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">rare</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="707.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">see</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="707.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">movi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="707.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">like</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">INTJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="707.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">rarelyfor</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="707.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">movi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="707.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">nearli</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="707.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">par</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="707.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">shawshank</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="707.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">redempt</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="707.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">actual</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="707.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">littl</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="707.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">bit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="707.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">ahead</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="707.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">interstellar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="707.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">howev</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="707.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">film</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="707.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">common</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="707.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">top</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="707.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">time</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="707.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">contain</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="707.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">power</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="707.0">
#     <tspan class="displacy-word" fill="currentColor" x="2810">stori</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2810">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="707.0">
#     <tspan class="displacy-word" fill="currentColor" x="2930">mani</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2930">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="707.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">mani</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="707.0">
#     <tspan class="displacy-word" fill="currentColor" x="3170">movi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="707.0">
#     <tspan class="displacy-word" fill="currentColor" x="3290">good</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3290">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="707.0">
#     <tspan class="displacy-word" fill="currentColor" x="3410">fact</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3410">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="707.0">
#     <tspan class="displacy-word" fill="currentColor" x="3530">even</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3530">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="707.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">lot</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="c
# Sentence: one man serv roman armi movi show gladiat live struggl surviv fight fear anger lot mighti arena rome coliseum also seen movi show mighti ancient rome recommend movi everyon like histori action adventur best movi time let prefac mention someth ridley scott fanboy hold probabl higher pantheon modern filmmak dont mind admit howev one film seem step direct audienc feel neg toward posit probabl one film he prais gladiat ive sever view past coupl decad begin sort im disengag larg swath film think write downth stori spanish gener maximu russel crow built well ill say script john logan david franzoni william nicholson structur point need tell stori reveng there earli glori emperor marcu aureliu richard harri unjust fall hand commodu joaquin phoenix rebirth gladiatori game provinc ownership proximo oliv reed revel back forth toward reveng end yet cant connect ive lay blame film tone recent view refin criticismfirstli tone remark dour bare happi moment throughout exceedingli rare leav rest film oppress sen dour root idea film bandi cours begin fact maximu famili murder corrupt emperor kill father gain throne think one center problem tone lucilla conni nielsen commodu sister maximu previou relationship year ago seem kind feminin respit masculin around she almost written like man outsid look
# Parts of Speech:
# one/NUM man/NOUN serv/NOUN roman/PROPN armi/PROPN movi/PROPN show/VERB gladiat/PROPN live/VERB struggl/PROPN surviv/PROPN fight/PROPN fear/VERB anger/NOUN lot/NOUN mighti/VERB arena/PROPN rome/PROPN coliseum/NOUN also/ADV seen/VERB movi/PROPN show/NOUN mighti/VERB ancient/ADJ rome/PROPN recommend/VERB movi/PROPN everyon/NOUN like/ADP histori/NOUN action/NOUN adventur/ADV best/ADJ movi/PROPN time/NOUN let/VERB prefac/NOUN mention/VERB someth/ADJ ridley/NOUN scott/PROPN fanboy/PROPN hold/VERB probabl/ADJ higher/ADJ pantheon/NOUN modern/ADJ filmmak/NOUN do/AUX nt/PART mind/VERB admit/VERB howev/NOUN one/NUM film/NOUN seem/VERB step/NOUN direct/ADJ audienc/NOUN feel/VERB neg/ADJ toward/ADP posit/NOUN probabl/ADJ one/NUM film/NOUN he/PRON prais/PROPN gladiat/PROPN i/PRON ve/AUX sever/ADJ view/NOUN past/ADP coupl/PROPN decad/PROPN begin/VERB sort/ADV i/PRON m/VERB disengag/NOUN larg/NOUN swath/NOUN film/NOUN think/VERB write/VERB downth/ADJ stori/NOUN spanish/ADJ gener/PROPN maximu/PROPN russel/NOUN crow/NOUN built/VERB well/ADV ill/ADJ say/VERB script/NOUN john/PROPN logan/PROPN david/PROPN franzoni/PROPN william/PROPN nicholson/PROPN structur/PROPN point/NOUN need/NOUN tell/VERB stori/NOUN reveng/NOUN there/ADV earli/PROPN glori/PROPN emperor/PROPN marcu/PROPN aureliu/PROPN richard/PROPN harri/PROPN unjust/ADJ fall/VERB hand/NOUN commodu/NOUN joaquin/PROPN phoenix/PROPN rebirth/PROPN gladiatori/PROPN game/PROPN provinc/PROPN ownership/NOUN proximo/VERB oliv/PROPN reed/PROPN revel/NOUN back/ADV forth/ADV toward/ADP reveng/PROPN end/NOUN yet/ADV ca/AUX nt/PART connect/VERB i/PRON ve/AUX lay/VERB blame/NOUN film/NOUN tone/NOUN recent/ADJ view/NOUN refin/NOUN criticismfirstli/PROPN tone/PROPN remark/PROPN dour/PROPN bare/PROPN happi/NOUN moment/NOUN throughout/ADP exceedingli/NOUN rare/ADJ leav/NOUN rest/NOUN film/NOUN oppress/PROPN sen/PROPN dour/PROPN root/PROPN idea/NOUN film/NOUN bandi/PROPN cours/NOUN begin/VERB fact/NOUN maximu/NOUN famili/ADJ murder/NOUN corrupt/ADJ emperor/NOUN kill/VERB father/NOUN gain/NOUN throne/NOUN think/VERB one/NUM center/NOUN problem/NOUN tone/NOUN lucilla/PROPN conni/PROPN nielsen/PROPN commodu/PROPN sister/PROPN maximu/NOUN previou/PROPN relationship/NOUN year/NOUN ago/ADV seem/VERB kind/ADV feminin/ADJ respit/NOUN masculin/PROPN around/ADP she/PRON almost/ADV written/VERB like/ADP man/NOUN outsid/NOUN look/VERB
# Constituency Parsing Tree:
# one man serv roman armi movi/nsubj gladiat/dobj movi show/nsubj ancient rome/dobj movi everyon/dobj histori action/pobj prefac/nsubj someth ridley scott fanboy/nsubj probabl higher pantheon modern filmmak/nsubj howev one film/nsubj step direct audienc/nsubj posit probabl one film/pobj he/nsubj gladiat/dobj i/nsubj view/dobj coupl decad/pobj i/dobj disengag larg swath film/nsubj downth stori/dative spanish gener maximu russel crow/dobj say script john logan david franzoni william nicholson structur point need/nsubj stori reveng/dobj earli glori emperor marcu aureliu richard harri/dobj unjust fall hand commodu joaquin phoenix rebirth gladiatori game provinc ownership proximo oliv reed revel/dobj reveng end/pobj i/nsubj blame film tone/dobj dour bare happi moment/dobj exceedingli rare leav rest film oppress sen dour root idea film bandi cours/pobj maximu famili murder corrupt emperor/nsubj father gain throne/nsubj one center problem tone lucilla conni nielsen commodu sister maximu previou relationship/nsubj kind feminin respit masculin/nsubj she/pobj man outsid/pobj
# Dependency Parsing Tree:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="9a8313499c4f493fa8494935d49d10b4-0" class="displacy" width="25490" height="737.0" direction="ltr" style="max-width: none; height: 737.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">one</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">man</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">serv</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">roman</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">armi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">movi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">show</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">gladiat</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">live</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">struggl</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">surviv</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">fight</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">fear</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">anger</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">lot</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">mighti</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">arena</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">rome</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">coliseum</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">also</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">seen</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">movi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">show</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2810">mighti</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2810">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2930">ancient</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2930">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">rome</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="3170">recommend</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3170">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="3290">movi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3290">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="3410">everyon</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3410">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="3530">like</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3530">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">histori</tspan>
#     <tspan class="displacy-tag" dy="2em"
# Sentence: she terribl feminin hard cold even begin given one moment smile laugh maximu expens otherwis much respit form miseri around even maximu she never potenti alli dark danger gameth time film lighten tone action sequenc gener pretti great scott qualiti action filmmak understand point spectacl achiev battl germania fight africa gladiatori bout coliseum expertli stage film film begin strong recreat roman battl tactic help han zimmer lisa gerrard rous score get lost dour tone machin roman senateand lead second main critic polit there point later commodu quizz lucilla peopl rome like distant victori repli glori rome idea definit larger plot film return glori rome preimperi state republ without emperor
# Parts of Speech:
# she/PRON terribl/VERB feminin/ADJ hard/ADJ cold/NOUN even/ADV begin/VERB given/VERB one/NUM moment/NOUN smile/NOUN laugh/NOUN maximu/NOUN expens/NOUN otherwis/ADP much/ADJ respit/NOUN form/NOUN miseri/ADJ around/ADP even/ADV maximu/VERB she/PRON never/ADV potenti/VERB alli/PROPN dark/PROPN danger/PROPN gameth/PROPN time/NOUN film/NOUN lighten/VERB tone/NOUN action/NOUN sequenc/NOUN gener/PROPN pretti/PROPN great/ADJ scott/NOUN qualiti/PROPN action/NOUN filmmak/NOUN understand/VERB point/NOUN spectacl/PROPN achiev/PROPN battl/PROPN germania/PROPN fight/PROPN africa/PROPN gladiatori/PROPN bout/NOUN coliseum/NOUN expertli/NOUN stage/NOUN film/NOUN film/NOUN begin/VERB strong/ADJ recreat/NOUN roman/ADJ battl/NOUN tactic/NOUN help/PROPN han/PROPN zimmer/PROPN lisa/PROPN gerrard/VERB rous/ADJ score/NOUN get/AUX lost/VERB dour/ADJ tone/NOUN machin/VERB roman/ADJ senateand/NOUN lead/VERB second/ADJ main/ADJ critic/NOUN polit/VERB there/ADV point/NOUN later/ADV commodu/PROPN quizz/PROPN lucilla/PROPN peopl/PROPN rome/PROPN like/ADP distant/ADJ victori/NOUN repli/NOUN glori/PROPN rome/PROPN idea/PROPN definit/PROPN larger/ADJ plot/NOUN film/NOUN return/VERB glori/PROPN rome/PROPN preimperi/PROPN state/NOUN republ/NOUN without/ADP emperor/NOUN
# Constituency Parsing Tree:
# she/nsubj feminin hard cold/nsubj one moment smile/pobj laugh maximu expens/dobj much respit form/pobj she/nsubj alli dark danger/dobj gameth time film lighten tone action sequenc gener pretti great scott qualiti action filmmak/nsubj point spectacl achiev battl germania fight africa gladiatori bout coliseum expertli stage film film/nsubj strong recreat roman battl tactic help/dobj han zimmer lisa/nsubj rous score/nsubjpass dour tone/nsubj roman senateand/dobj distant victori repli glori rome idea definit larger plot film return glori rome preimperi state republ/pobj emperor/pobj
# Dependency Parsing Tree:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="1fa5c7345b6f4847897f78ad1e288e60-0" class="displacy" width="13130" height="737.0" direction="ltr" style="max-width: none; height: 737.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">she</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">terribl</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">feminin</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">hard</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">cold</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">even</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">begin</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">given</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">one</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">moment</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">smile</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">laugh</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">maximu</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">expens</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">otherwis</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">much</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">respit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">form</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">miseri</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">around</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">even</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">maximu</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">she</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2810">never</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2810">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2930">potenti</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2930">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">alli</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="3170">dark</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="3290">danger</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3290">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="3410">gameth</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3410">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="3530">time</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">film</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="curre
# Sentence: okay fine never make case preimperi state better way current state never dig maximu care beyond fact die wish marcu aureliu would real one want doesnt matter movieand lead think core issu film maximu strong reason want plot actual want reveng commodu enough there effort wrap effort senat led gracchu derek jacobi commodu return power senat pervers incent commodu point suppos ignor reason maximu care marcu aureliu told care essenti real disconnect film present charact interact plot film never actual reconcilesand yet think
# Parts of Speech:
# okay/ADJ fine/NOUN never/ADV make/VERB case/NOUN preimperi/ADJ state/NOUN better/ADJ way/NOUN current/ADJ state/NOUN never/ADV dig/VERB maximu/NOUN care/NOUN beyond/ADP fact/NOUN die/NOUN wish/VERB marcu/NOUN aureliu/NOUN would/AUX real/VERB one/NUM want/NOUN does/AUX nt/PART matter/VERB movieand/NOUN lead/NOUN think/VERB core/PROPN issu/PROPN film/PROPN maximu/PROPN strong/ADJ reason/NOUN want/VERB plot/NOUN actual/ADJ want/VERB reveng/PROPN commodu/NOUN enough/ADV there/PRON effort/VERB wrap/NOUN effort/NOUN senat/NOUN led/VERB gracchu/PROPN derek/PROPN jacobi/PROPN commodu/PROPN return/PROPN power/NOUN senat/NOUN pervers/NOUN incent/VERB commodu/NOUN point/NOUN suppos/NOUN ignor/NOUN reason/NOUN maximu/NOUN care/NOUN marcu/NOUN aureliu/PROPN told/VERB care/NOUN essenti/VERB real/ADJ disconnect/ADJ film/NOUN present/ADJ charact/NOUN interact/NOUN plot/NOUN film/NOUN never/ADV actual/ADJ reconcilesand/NOUN yet/ADV think/VERB
# Constituency Parsing Tree:
# okay fine/nsubj case/nsubj current state/nsubj maximu care/dobj fact/pobj marcu aureliu/nsubj want/dobj movieand lead/nsubj core issu film maximu strong reason/nsubj wrap effort senat/nsubj gracchu derek jacobi commodu return power senat pervers/nsubj commodu point suppos ignor reason maximu care marcu aureliu/nsubj care/dobj essenti real disconnect film/dobj present charact interact plot film/appos never actual reconcilesand/dobj
# Dependency Parsing Tree:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="435fe92cd00c47f880893774e7e8eca2-0" class="displacy" width="10130" height="617.0" direction="ltr" style="max-width: none; height: 617.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">okay</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">fine</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">never</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">make</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">case</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">preimperi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">state</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">better</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">way</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">current</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">state</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">never</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">dig</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">maximu</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">care</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">beyond</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">fact</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">die</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">wish</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">marcu</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">aureliu</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">would</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">real</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2810">one</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2810">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="2930">want</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2930">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">does</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="3170">nt</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3170">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="3290">matter</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="3410">movieand</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3410">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="3530">lead</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="527.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">think</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3
# Sentence: film pretti
# Parts of Speech:
# film/NOUN pretti/PROPN
# Constituency Parsing Tree:
# film/nsubj
# Dependency Parsing Tree:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e4d936a61baf424b9acb15e79b29d790-0" class="displacy" width="290" height="197.0" direction="ltr" style="max-width: none; height: 197.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="107.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">film</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="107.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">pretti</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e4d936a61baf424b9acb15e79b29d790-0-0" stroke-width="2px" d="M70,62.0 C70,2.0 170.0,2.0 170.0,62.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e4d936a61baf424b9acb15e79b29d790-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,64.0 L62,52.0 78,52.0" fill="currentColor"/>
# </g>
# </svg></span>
# Sentence: okay
# Parts of Speech:
# okay/INTJ
# Constituency Parsing Tree:
#
# Dependency Parsing Tree:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="3c60c862e46c48359ac8adc9a0a7a886-0" class="displacy" width="170" height="137.0" direction="ltr" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">okay</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">INTJ</tspan>
# </text>
# </svg></span>
# Sentence: mostli spectacl front give film full mark look great begin end there painterli approach visual help small part scott penchant use smoke machin everywher ever make film im use smoke machin ridley scott fault action scene topnotch perform everyon commit effect
# Parts of Speech:
# mostli/PROPN spectacl/PROPN front/NOUN give/VERB film/NOUN full/ADJ mark/NOUN look/VERB great/ADJ begin/NOUN end/VERB there/ADV painterli/ADJ approach/NOUN visual/ADJ help/NOUN small/ADJ part/NOUN scott/PROPN penchant/PROPN use/NOUN smoke/NOUN machin/NOUN everywher/NOUN ever/ADV make/VERB film/NOUN i/PRON m/AUX use/VERB smoke/NOUN machin/PROPN ridley/NOUN scott/PROPN fault/PROPN action/NOUN scene/NOUN topnotch/NOUN perform/VERB everyon/NOUN commit/VERB effect/NOUN
# Constituency Parsing Tree:
# mostli/nsubj spectacl front/appos film/dative full mark/nsubj painterli approach visual help/dative small part/dobj scott penchant use smoke/appos machin everywher/nsubj film/dobj i/nsubj smoke machin ridley scott fault action scene topnotch/dobj everyon/dobj effect/dobj
# Dependency Parsing Tree:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e6aea8e5f63b4a5aa2f7a5dc3a72c009-0" class="displacy" width="5090" height="557.0" direction="ltr" style="max-width: none; height: 557.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">mostli</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">spectacl</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">front</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">give</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">film</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">full</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">mark</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">look</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">great</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">begin</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">end</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">there</tspan>
# ...
# Constituency Parsing Tree:
# visual becom sensori feast bittersweet end linger/nsubj mere sword sandal/nsubj power tale resili wit crow epic roar betray gener turn/dobj gladiat vengeanc simmer unforgiv colosseum rome/dobj honor/pobj ancient rome cinemat journey histor spectacl profound narr strength honor/appos long final scene/dobj super good movi/nsubj area movi domain/pobj stun plea/nsubj trust good tri spoil anyth/dobj rullel cruel phinx super good movi/nsubj agre movi movi good/dobj sorta/nsubj mean sweep saga ancient rome reveng redempt cinemat triumph/nsubj breathtak action sequenc unforgett/nsubj timeless soundtrack rank/dobj greatest cinema historyset turbul world roman empir gladiat/pobj stori maximu decimu meridiu rever roman gener betray murder powerhungri emperor commodu maximu/nsubj enslav vow aveng famili emperora maximu rise rank gladiatori arena becom symbol hope/nsubj oppress roman citizen/dobj unwav determin/dobj prowess captur heart/dobj justic vengeanc fuel unwav resolveridley/appos scott direct master creat immers visual stun experi transport viewer heart/appos ancient rome cinematographi breathtak/nsubj vast colosseum grandeur rome architectur brutal gladiatori combat action sequenc expertli choreograph/dobj deliv viscer thrill thrill emot chargedrussel crow deliv tourdeforc perform maximu captur charact strength/nsubj unwav determin crow/nsubj truli unforgett figur joaquin phoenix/nsubj captiv commodu portray emperor powerhungri ruthless tyrant phoenix/nsubj chill mesmer/dobj commodu complex compel villaingladi soundtrack compos han zimmer masterpiec right score emot/nsubj epic grandeur emot depth zimmer score/appos gladiat film/nsubj endur strength/pobj cinemat triumph film transport/dobj anoth world immers captiv stori/dobj leav/dobj last emot impact/nsubj russel crow deliv command/nsubj maximu portray charact driven honor justic joaquin phoenix/nsubj compel sinist commodu ad depth film explor power corrupt support/dobj cast includ conni nielsen djimon hounsou contribut overal strength ensembl han zimmer power evoc music score complement film emot intens/nsubj sweep orchestr/dobj arrang enhanc/dobj creat memor impact auditori experiencegladi delv theme betray redempt cost/nsubj justic charact maximu embodi struggl oppress colosseum becom symbol arena physic moral battl film/nsubj corrupt natur power desir legaci/dobj releas gladiat/pobj widespread critic acclaim/appos achiev commerci success/appos five academi award/nsubj endur popular attribut engag narr/nsubj visual memor performancesgladi/nsubj scott direct coupl russel/appos crow stellar portray maximu creat endur epic continu captiv audienc/nsubj narr/nsubj intrigu support/nsubj includ joaquin phoenix/oprd conni nielsen complement crow/appos creat cast ensembl/dobj mere actionpack spectacl characterdriven epic explor theme sacrific resili human spirit impact/conj endur memor quot scene/nsubj cinemat histori gladiat/dobj star rate/dobj cinemat grandeur compel storytel timeless reson maximuss journey triumph continu/nsubj tall pantheon great film ridley scott gladiat perfect film/nsubj hardiest fan/dobj i/dobj commodu film/pobj keen point/appos gladiat/nsubj enough fact/dobj everlast favourit genr fan worthi academi award acknowledg/nsubj never shi away knowledg/nsubj anthoni mann epic fall roman empir folk/nsubj irrit strang maker gladiat/nsubj bold brass proclaim/dobj uniqu movi reinvigor/appos stagnant genr film new gener audienc bloodi/nsubj influenc interest thing/dobj seewhat life/nsubj littl mug act support rank/nsubj struggl grasp period set requir/dobj gladiat/nsubj overrid film/nsubj irk crow maximu man men/nsubj man woman/nsubj day/pobj still much entertain phoenix antogonist crow/nsubj big screen experi tv home/dobj also much watchabl director caeser shoot beauti materi piec/nsubj paint explampl/pobj rome tijger chain lot/dobj zuccabar dessert/dobj move/nsubj classic han zimmer/pobj unforgett/nsubj audienc emot rollercoast rivet tale maximu decimu meridiu russel cr ...
# Dependency Parsing Tree:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4e515dba8d85464cbac19007ca6a32af-0" class="displacy" width="146810" height="3137.0" direction="ltr" style="max-width: none; height: 3137.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3047.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">visual</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3047.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">becom</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3047.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">sensori</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3047.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">feast</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3047.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">bittersweet</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3047.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">end</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3047.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">linger</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3047.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">transcend</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3047.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">mere</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3047.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">sword</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3047.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">sandal</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3047.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">tell</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3047.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">power</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3047.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">tale</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3047.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">resili</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3047.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">wit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3047.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">crow</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3047.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">epic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3047.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">roar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3047.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">betray</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3047.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">gener</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3047.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">turn</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3047.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">gladiat</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3047.0">
#     <tspan class="displacy-word" fill="currentColor" x="2810">vengeanc</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2810">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3047.0">
#     <tspan class="displacy-word" fill="currentColor" x="2930">simmer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2930">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3047.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">unforgiv</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3047.0">
#     <tspan class="displacy-word" fill="currentColor" x="3170">colosseum</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3047.0">
#     <tspan class="displacy-word" fill="currentColor" x="3290">rome</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3290">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3047.0">
#     <tspan class="displacy-word" fill="currentColor" x="3410">underneath</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3410">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3047.0">
#     <tspan class="displacy-word" fill="currentColor" x="3530">honor</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="3047.0">
#     <tspan class="displacy-word" fill="currentColor

# %% [markdown]
# # Mandatory Question
#
# Provide your thoughts on the assignment. What did you find challenging, and what aspects did you enjoy? Your opinion on the provided time to complete the assignment.

# %%
# Write your response below
